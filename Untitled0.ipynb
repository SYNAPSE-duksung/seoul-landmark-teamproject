# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/seoul-landmark-teamproject
# Out:
# /content/drive/MyDrive/seoul-landmark-teamproject

# %%
# !ls
# Out:
# cnn_baseline.ipynb  submission_transfer.csv  시냅스_팀프로젝트D_보고서.docx
# README.md	    transfer_learning.ipynb
# submission_cnn.csv  Untitled0.ipynb

# %%
# !git branch -a
# Out:
#   main
# * team-D
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/main
#   remotes/origin/team-A
#   remotes/origin/team-B
#   remotes/origin/team-C
#   remotes/origin/team-D
